# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # oke
# ## oke
# ### oke

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %%
print(df.target.value_counts())
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# # problem definition
# ### this is the problem deffinition

# %% [markdown]
# ##

# %% [markdown]
# Data
# ### this is our data

# %% [markdown]
# series dalam 1 dimensi

# %%
series = pd.Series(["bmw","toyota","honda"])

# %%
series
# Out:
# 0       bmw
# 1    toyota
# 2     honda
# dtype: object

# %%
colours = (["red","green","blue"])
colours
# Out:
# ['red', 'green', 'blue']

# %% [markdown]
# dataframe dalam 2 dimensi

# %%
car_data = pd.DataFrame({"car make": series, "Colour": colours})
car_data
# Out:
#   car make Colour
# 0      bmw    red
# 1   toyota  green
# 2    honda   blue

# %%
# import data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#exporting dataframe
car_sales.to_csv("exported-car-sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#atribut
car_sales.dtypes

#function (ada kurung)
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() #hanya menampilkan kolom numerik
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_prices  = pd.Series([3000,1500,111250])
print(car_prices.mean())
car_prices.sum()
# Out:
# 38583.333333333336
# 115750

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # viewing and selecting data

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail(4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # .loc and .iloc

# %%
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index = [0, 4, 9, 8, 2])
animals
# Out:
# 0      cat
# 4      dog
# 9     bird
# 8    panda
# 2    snake
# dtype: object

# %%
animals.loc[2]
# Out:
# 'snake'

# %%
car_sales.loc[4] # the key/index
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
animals.iloc[2] #position from start
# Out:
# 'bird'

# %%
animals.iloc[:3] #to 3
# Out:
# 0     cat
# 4     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make #cant call column with space
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"] #only call toyota make
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Colour"], car_sales["Doors"]) # compare 2 columns
# Out:
# Doors   3  4  5
# Colour
# Black   0  0  1
# Blue    1  2  0
# Green   0  1  0
# Red     0  1  0
# White   0  4  0

# %%
pd.crosstab(car_sales["Make"], car_sales["Price"])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
# groupby
car_sales.groupby(["Make"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Documents\AnacondaEnv\project_1\env\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\Documents\AnacondaEnv\project_1\env\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\Documents\AnacondaEnv\project_1\env\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# import data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("$","").str.replace(",", "").astype(float).astype(int)

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower() # reassign the variable

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## if some data is missing

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                    inplace = True) #sama saja dengan perintah diatasnya

# %%
car_sales_missing #
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna() #hanya menampilkan data lengkap
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
dropped = car_sales_missing.dropna()#saat membuat salinan, jangan menggunakan inplace

# %%
dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
seats_column = pd.Series([5,5,5,5,5])

car_sales["seats"] = seats_column

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["seats"].fillna(5, inplace=True)
car_sales
# Out:
# C:\Users\ergik\AppData\Local\Temp\ipykernel_13244\3880422171.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["seats"].fillna(5, inplace=True)
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# ...

# %% [markdown]
# ### catatan : jika list dideklarasi kemudian dimasukkan sebagai kolom, maka banyak data pada list harus sesuai dengan banyak data pada csv.
# ### namun jika dimasukkan langsung kedalam list dengan langsung menamai kolomnya, maka banyak data bisa berbeda dengan banyak data di csv, kekurangan data akan ditandai NaN

# %%
fuel = [8,9.5,7,5.0,4.5,6.0,3,7,8,10] #
car_sales["fuel"] = fuel
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel
# 0  toyota  White         150043      4   4000    5.0   8.0
# 1   honda    Red          87899      4   5000    5.0   9.5
# 2  toyota   Blue          32549      3   7000    5.0   7.0
# 3     bmw  Black          11179      5  22000    5.0   5.0
# 4  nissan  White         213095      4   3500    5.0   4.5
# 5  toyota  Green          99213      4   4500    5.0   6.0
# 6   honda   Blue          45698      4   7500    5.0   3.0
# 7   honda   Blue          54738      4   7000    5.0   7.0
# 8  toyota  White          60000      4   6250    5.0   8.0
# 9  nissan  White          31600      4   9700    5.0  10.0

# %%
car_sales["used fuel"] = car_sales["Odometer (KM)"]/100 * car_sales["fuel"] #fuel is for 100km usage

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000

# %%
car_sales["Number of Wheel"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
#
#    Number of Wheel
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# ...

# %%
car_sales["safety"] = True
car_sales.dtypes
# Out:
# Make                object
# Colour              object
# Odometer (KM)        int64
# Doors                int64
# Price                int32
# seats              float64
# fuel               float64
# used fuel          float64
# Number of Wheel      int64
# safety                bool
# dtype: object

# %% [markdown]
# axis = 1 digunakan untuk memilih kolom, dan axis 0 digunakan untuk memilih baris. jika tidak ditulis, maka akan secara otomatis menggunakan axis 0

# %%
car_sales.drop("safety", axis=1) #ingat untuk menggunakan parameter axis
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
#
#    Number of Wheel
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# ...

# %%
car_sales.drop(2, axis=0) #ingat untuk menggunakan parameter axis
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
#
#    Number of Wheel  safety
# 0                4    True
# 1                4    True
# 3                4    True
# 4                4    True
# 5                4    True
# 6                4    True
# 7                4    True
# 8                4    True
# ...

# %%
shuffled = car_sales.sample(frac=1) #mengacak seluruh data

# %%
car_sales.sample(frac=0.7)#mengacak data dan mengambil 70 % dari data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
#
#    Number of Wheel  safety
# 3                4    True
# 7                4    True
# 4                4    True
# 1                4    True
# 9                4    True
# 2                4    True
# 5                4    True

# %%
shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
#
#    Number of Wheel  safety
# 1                4    True
# 7                4    True
# 6                4    True
# 4                4    True
# 3                4    True
# 2                4    True
# ...

# %%
shuffled.reset_index(drop = True,inplace=True) # drop tidak menambah index tambahan di kiri

# %%
shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 0   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 1   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 2   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 3  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 4     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 5  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 6  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 7  nissan  White          31600      4   9700    5.0  10.0   3160.000
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  toyota  White         150043      4   4000    5.0   8.0  12003.440
#
#    Number of Wheel  safety
# 0                4    True
# 1                4    True
# 2                4    True
# 3                4    True
# 4                4    True
# 5                4    True
# ...

# %%
car_sales["Odometer (Mil)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6) #apply menggunakan fungsi

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  fuel  used fuel  \
# 0  toyota  White         150043      4   4000    5.0   8.0  12003.440
# 1   honda    Red          87899      4   5000    5.0   9.5   8350.405
# 2  toyota   Blue          32549      3   7000    5.0   7.0   2278.430
# 3     bmw  Black          11179      5  22000    5.0   5.0    558.950
# 4  nissan  White         213095      4   3500    5.0   4.5   9589.275
# 5  toyota  Green          99213      4   4500    5.0   6.0   5952.780
# 6   honda   Blue          45698      4   7500    5.0   3.0   1370.940
# 7   honda   Blue          54738      4   7000    5.0   7.0   3831.660
# 8  toyota  White          60000      4   6250    5.0   8.0   4800.000
# 9  nissan  White          31600      4   9700    5.0  10.0   3160.000
#
#    Number of Wheel  safety  Odometer (Mil)
# 0                4    True       93776.875
# 1                4    True       54936.875
# 2                4    True       20343.125
# ...
